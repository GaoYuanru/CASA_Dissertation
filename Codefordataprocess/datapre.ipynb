# %%
import requests
import json

params = {
    "token": "uclapi-f14c455679d6f8f-8fbfd61b137ba27-8a96d3c8a026f95-e5d621f791d6d53",
    "date": "20230522",
    "results_per_page": "1",
}

r = requests.get("https://uclapi.com/workspaces/sensors/summary", params=params)
data = r.json()

# 导出为JSON文件
filename = "outputn.json"
with open(filename, "w") as json_file:
    json.dump(data, json_file, indent=4)

print("数据已成功导出为JSON文件:", filename)
# Out:
# 数据已成功导出为JSON文件: outputn.json

# %%
import requests

params = {
	 "token": "uclapi-f14c455679d6f8f-8fbfd61b137ba27-8a96d3c8a026f95-e5d621f791d6d53",
    "survey_id": "8"
  
	 
}
r9 = requests.get("https://uclapi.com/workspaces/sensors", params=params)
print(r9.json())
data = r9.json()

# 导出为JSON文件
filename9 = "outputn9.json"
with open(filename9, "w") as json_file:
    json.dump(data, json_file, indent=4)

print("数据已成功导出为JSON文件:", filename9)
# Out:
# {'ok': True, 'maps': [{'id': '97', 'name': 'Bartlett', 'image_id': '106', 'sensors': {'578001': {'hardware_id': '578001', 'x_pos': '32848.0', 'y_pos': '4212.0', 'survey_id': '8', 'survey_device_id': '32845', 'host_address': '578', 'pir_address': '1', 'device_type': 'Desk', 'location': '', 'description_1': '', 'description_2': '', 'description_3': 'ST', 'room_id': '10', 'room_name': 'G16', 'share_id': 'None', 'floor': '0', 'room_type': 'Open Plan', 'building_name': 'Central House', 'room_description': '', 'last_trigger_timestamp': '2023-05-22T15:36:55+01:00', 'last_trigger_type': 'Absent', 'occupied': False}, '578002': {'hardware_id': '578002', 'x_pos': '32809.0', 'y_pos': '5182.0', 'survey_id': '8', 'survey_device_id': '32846', 'host_address': '578', 'pir_address': '2', 'device_type': 'Desk', 'location': '', 'description_1': '', 'description_2': '', 'description_3': 'ST', 'room_id': '10', 'room_name': 'G16', 'share_id': 'None', 'floor': '0', 'room_type': 'Open Plan', 'building_name':
# ...

# %%
# Out:
#   Input In [22]
#     "image_id":"106"
#     ^
# SyntaxError: invalid syntax

# %%
import requests

params = {
    "token": "uclapi-f14c455679d6f8f-8fbfd61b137ba27-8a96d3c8a026f95-e5d621f791d6d53",
    "survey_id": "8",
    "map_id": "97"
}

response = requests.get("https://uclapi.com/workspaces/images/map/live", params=params)

if response.status_code == 200:
    # 输出XML响应
    xml_data = response.text
    print(xml_data)
else:
    print("Error:", response.json()["error"])
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:ev="http://www.w3.org/2001/xml-events">
#   <g transform="scale(0.02, 0.02)">
#     <image width="48190" height="28498" xlink:href="data:image/png;base64,..."/>
#     <g>
#       <g id="578001" transform="translate(32848.0,4212.0)">
#         <circle r="128.0" fill="#FFC90E"/>
#       </g>
#       <g id="578002" transform="translate(32809.0,5182.0)">
#         <circle r="128.0" fill="#FFC90E"/>
#       </g>
#       <g id="578003" transform="translate(31973.0,5146.0)">
#         <circle r="128.0" fill="#FFC90E"/>
#       </g>
#       <g id="578004" transform="translate(32017.0,4177.0)">
#         <circle r="128.0" fill="#FFC90E"/>
#       </g>
#       <g id="578005" transform="translate(29841.0,4145.0)">
#         <circle r="128.0" fill="#FFC90E"/>
#       </g>
#       <g id="578006" transform="translate(29802.0,5115.0)">
#         <circle r="128.0" fill="#ABE00C"/>
#       </g>
# ...

# %%
from bs4 import BeautifulSoup

# SVG code
svg_code ='''
<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:ev="http://www.w3.org/2001/xml-